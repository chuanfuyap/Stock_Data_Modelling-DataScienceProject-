# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pyflux as pf
import matplotlib.pyplot as plt
import statsmodels.tsa.api as smt
import statsmodels.tsa.stattools as sm
import scipy.stats as sp
from sklearn.metrics import mean_squared_error as rmse
from sklearn.linear_model import LinearRegression as lr

# %% [markdown]
# # Importing Microsoft stock data obtained from Quandl website and have a quick peek to see what the dataset contains

# %%
msft = pd.DataFrame.from_csv('MSFT.csv')
msft = msft.dropna()
msft.head()
# Out:
#              Open    High    Low  Close      Volume  Ex-Dividend  Split Ratio  \
# Date
# 2016-09-15  56.15  57.350  55.98  57.19  26435104.0          0.0          1.0
# 2016-09-14  56.39  56.630  56.03  56.26  23616182.0          0.0          1.0
# 2016-09-13  56.50  56.650  56.05  56.53  29465088.0          0.0          1.0
# 2016-09-12  56.00  57.205  55.61  57.05  28441578.0          0.0          1.0
# 2016-09-09  56.79  57.520  56.21  56.21  33475922.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 2016-09-15      56.15     57.350     55.98       57.19   26435104.0
# 2016-09-14      56.39     56.630     56.03       56.26   23616182.0
# 2016-09-13      56.50     56.650     56.05       56.53   29465088.0
# 2016-09-12      56.00     57.205     55.61       57.05   28441578.0
# 2016-09-09      56.79     57.520     56.21       56.21   33475922.0

# %% [markdown]
# # Q1 Can you count something interesting?

# %%
msft.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  7682.000000  7682.000000  7682.000000  7682.000000  7.682000e+03
# mean     59.214550    60.066258    58.395240    59.259573  3.152511e+07
# std      33.128003    33.654626    32.599529    33.166756  3.266399e+07
# min      15.200000    15.620000    14.870000    15.150000  8.000000e+03
# 25%      28.620000    28.902500    28.312500    28.592500  2.097475e+06
# 50%      52.620000    53.492500    51.785000    52.685000  2.706805e+07
# 75%      84.000000    85.202500    82.750000    84.000000  5.111178e+07
# max     178.940000   180.380000   175.750000   179.940000  5.910522e+08
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count  7682.000000  7682.000000  7682.000000  7682.000000  7682.000000
# mean      0.001530     1.001041    16.624289    16.816607    16.437196
# std       0.038512     0.031231    13.699375    13.836959    13.567719
# ...

# %%
178/15
# Out:
# 11

# %% [markdown]
# On average, Closing value is higher then Opening value slightly. While the highest traded is 11 times highest than the lowest traded value.

# %% [markdown]
# # As the data contains multiple data, I will focus on just the Open stock values

# %%
msftO = msft.Open

plt.figure(figsize=(17,7))
plt.title('Microsoft Opening Stock Data from year March 1986 to Sept 2016')
plt.xlabel('Time (Year)')
plt.ylabel('Stock Value')

msftplot = msftO.plot()

# %% [markdown]
# # Q2 Can you find some trends (high, low, increase, decrease, anomalies)?
# Before the year 2003, stock value fluctuates immensely with rapid rise and stee;p drops happening at a glance from the plot. However after the year drop in 2003, (presumably linked to the recession) the stock prices seems to be more stable relative to previous years, until circa 2013 where the value increases slowly.

# %% [markdown]
# # Q3 Can you make a bar plot or a histogram?
# Yes, but as this is a time series data, line plot is better

# %%
plt.hist(msftO)
# Out:
# (array([ 2587.,   863.,  1372.,   758.,  1003.,   498.,   316.,   199.,
#            65.,    21.]),
#  array([  15.2  ,   31.574,   47.948,   64.322,   80.696,   97.07 ,
#          113.444,  129.818,  146.192,  162.566,  178.94 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Choosing Data for Time Series Model for Prediction
# As this is a massive dataset, I will only using a dataset from one year for quick model building with the idea of making predictions of future stock value. Which will be hopefully be validated with data of the following year. Two separate models will be built, one from pre 2003 which fluctuates a lot more and one from post 2003 which is more stable relatively. Data from year 1991 and 2005 will be used.

# %%
yr1991 = pd.date_range('1991-01-01', '1991-12-31', freq='D')
yr2005 = pd.date_range('2005-01-01', '2005-12-31', freq='D')

msft1991 = msft.loc[yr1991].dropna()
msft2005 = msft.loc[yr2005].dropna()
open1991 = msft1991.Open
open2005 = msft2005.Open

# %% [markdown]
# # First model for 1991

# %%
arima1991 = pf.ARIMA(msft1991, ar=1, ma=3, integ=1, target='Open')

# %%
fit1991 = arima1991.fit("MLE")

# %%
arima1991.plot_fit(figsize=(15,5))

# %% [markdown]
# # Completed 1991 arima model
# now let's make some prediction and compare with the original data, first I need to turn the differenced data back to the original scale

# %%
diffpred1992 = arima1991.predict(h=100)['Differenced Open']
yr1992 = pd.date_range(diffpred1992.index.min(), diffpred1992.index.max(), freq='D')
msft1992 = msft.loc[yr1992].interpolate().fillna(method='bfill')
ori1992 = msft1992.Open
diffpred1992[0]=ori1992[0]
pred1992=diffpred1992.cumsum()

# %%
pred1992 = pred1992.reindex(pd.date_range(start=pred1992.index.min(), end=pred1992.index.max(),freq='1D')) 
ori1992 = ori1992.reindex(pd.date_range(start=ori1992.index.min(), end=ori1992.index.max(),freq='1D')) 

pred1992 = pred1992.interpolate(method='time')
ori1992 = ori1992.interpolate(method='time')

pred1992.plot(color='red')
ori1992.plot(color='blue')

# %% [markdown]
# # Evaluating accuracy of the prediction
# After making prediction with the model and plotting the results, lets evaluate the prediction with correlation methods

# %%
#pearson correlation

pred1992list = np.array(pred1992.tolist())
ori1992list = np.array(ori1992.tolist())

print('Pearson Correlation Coeefiecient: ', sp.pearsonr(pred1992list, ori1992list))

error2 = [((x-y)/y)**2 for x, y in zip(pred1992list, ori1992list)]
print ("Normalised RMSE",np.sqrt(np.sum(error2)))
# Out:
# ('Pearson Correlation Coeefiecient: ', (0.77210508563271552, 6.009712741228849e-30))
# ('Normalised RMSE', 1.5477534314126267)

# %% [markdown]
# The pearson correlation coefficient indicates the prediction to have good correlation. While, the normalised Root-Mean-Squared-Error indicate the model is decent for prediction

# %% [markdown]
# # Lets try with 2005 data

# %%
arima2005 = pf.ARIMA(msft2005, ar=5, ma=5, integ=1, target='Open')

# %%
fit2005 = arima2005.fit()

# %%
arima2005.plot_fit(figsize=(15,5))

# %%
diffpred2006 = arima2005.predict(h=100)['Differenced Open']
yr2006 = pd.date_range(diffpred2006.index.min(), diffpred2006.index.max(), freq='D')
msft2006 = msft.loc[yr2006].interpolate().fillna(method='bfill')
ori2006 = msft2006.Open
diffpred2006[0]=ori2006[0]
pred2006=diffpred2006.cumsum()

# %%
pred2006 = pred2006.reindex(pd.date_range(start=pred2006.index.min(), end=pred2006.index.max(),freq='1D')) 
ori2006 = ori2006.reindex(pd.date_range(start=ori2006.index.min(), end=ori2006.index.max(),freq='1D')) 

pred2006 = pred2006.interpolate(method='time')
ori2006 = ori2006.interpolate(method='time')

pred2006.plot(color='red')
ori2006.plot(color='blue')

# %%
pred2006list = np.array(pred2006.tolist())
ori2006list = np.array(ori2006.tolist())

print('Pearson Correlation Coeefiecient: ', sp.pearsonr(ori2006list, pred2006list))

error2 = [((x-y)/y)**2 for x, y in zip(pred2006list, ori2006list)]
print ("Normalised RMSE",np.sqrt(np.sum(error2)))
# Out:
# ('Pearson Correlation Coeefiecient: ', (0.18179177295088458, 0.029782282955742614))
# ('Normalised RMSE', 0.32728604546078321)

# %% [markdown]
# The Correlation coefficient indicates that the prediction is not good, the normalised RMSE seem to be telling a different story.

# %% [markdown]
# # Pause on time series model prediction with ARIMA.
# It seems ARIMA alone isn't sufficient to make stable accurate predictions using available data. As stock values involve multiple variables such as investor involvement, additional dataset will be used help make predictions on the stock data. The additional data set will be investor sentiments, which is also obtained from Quandl.

# %% [markdown]
# # Q4 Can you compare two related quantities?
# Did that between predicted and original results

# %%
investor = pd.DataFrame.from_csv('investor.csv')
investor = investor.fillna(investor.mean())
investor.head()
# Out:
#              Bullish   Neutral   Bearish     Total  Bullish 8-Week Mov Avg  \
# Date
# 2016-08-25  0.294243  0.409382  0.296375  1.000000                0.325835
# 2016-08-18  0.355649  0.380753  0.263598  1.000000                0.325195
# 2016-08-11  0.312925  0.419501  0.267574  1.000000                0.308201
# 2016-08-04  0.297872  0.434397  0.267730  0.999999                0.300769
# 2016-07-28  0.312500  0.403409  0.284091  1.000000                0.298325
#
#             Bull-Bear Spread  Bullish Average  Bullish Average + St. Dev  \
# Date
# 2016-08-25         -0.002132         0.384424                   0.487691
# 2016-08-18          0.092051         0.384424                   0.487691
# 2016-08-11          0.045351         0.384424                   0.487691
# 2016-08-04          0.030142         0.384424                   0.487691
# 2016-07-28          0.028409         0.384424                   0.487691
#
#             Bullish Average - St. Dev  S&P 500 Weekly High  \
# ...

# %% [markdown]
# First lets see if there's and overall correlation between the 2 datasets. (Opening stock value will still be the main data being investigated)

# %%
week=investor.index 
msftclean=msft.loc[week, :]
msftclean=msftclean.interpolate()
op = msftclean.Open

# %%
plt.scatter(investor.Bullish, op, color='Blue')
plt.scatter(investor.Neutral, op, color = 'Red')
plt.scatter(investor.Bearish, op, color='Green')

# %% [markdown]
# # Q5 Can you make a scatterplot?
# Yes. However using two different datasets and as seen above, there isnt clear correlation visible from the scatter plot
#
# So I am going to use pearsson correlation in order to quantify it

# %%
bulllist = np.array((investor['Bullish'].tolist()))
bearlist = np.array((investor['Bearish'].tolist()))
neutlist = np.array((investor['Neutral'].tolist()))

oplist = np.array(op.tolist())

opbull = sp.pearsonr(oplist, bulllist)
opneut = sp.pearsonr(oplist, neutlist)
opbear = sp.pearsonr(oplist, bearlist)

print ('Correlation between Opening stock value and Bullish behaviour is: {0}'.format(opbull))
print ('Correlation between Opening stock value and Neutral behaviour is: {0}'.format(opneut))
print ('Correlation between Opening stock value and Bearish behaviour is: {0}'.format(opbear))
# Out:
# Correlation between Opening stock value and Bullish behaviour is: (0.023530690503452197, 0.3592645328416656)
# Correlation between Opening stock value and Neutral behaviour is: (0.34838347693920141, 1.3047070925142473e-44)
# Correlation between Opening stock value and Bearish behaviour is: (-0.33757315489237244, 7.9317870664451983e-42)

# %% [markdown]
# When investors are bullish, they have no effect on the stock of microsoft.
# However when investors are neutral, they have a slight positive effect on the stock value of microsoft.
# And when the investors are bearish, they bring about a negative effect on microsoft's stock.

# %% [markdown]
# # Regression Model
# With the knowledge that Neutral behaviour there is positive correlation, lets try and build a linear regression model. Seeing that arima model of year 2005 have a better normalised rmse value, lets revisit that data.
